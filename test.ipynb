# %%
import numpy as np
import pandas as pd

data_raw = pd.read_csv("raw_labels_50.csv")
datat_true = pd.read_csv("true_labels_50.csv")
data = pd.concat([data_raw, datat_true], axis=1)
data
# Out:
#                                  Неправильный вариант
# 0   Этапы отбора:1. Подача заявок (до 19 июня);2. ...  \
# 1   По всем вопросам вы можете обращаться по эл. п...
# 2   Некоторые из волонтерских задач:Привлечение за...
# 3   возраст кандидата не менее 18 лет (на момент п...
# 4   Сроки привлечения волонтеров: с 29 августа по ...
# 5   По всем вопросам вы можете обращаться по эл. п...
# 6   Регистрируйся на портале DOBRO.ru!\nДо встречи...
# 7   Климатический урок разработан в двух вариантах...
# 8   Приглашаем волонтеров:для проведения веселых с...
# 9   опыт в бумажную личную книжку волонтера (ЛКВ) ...
# 10  Каждый волонтёр получит:Верифицированные часы ...
# 11  Особенностями волонтерской программы в этом го...
# 12  Информация о событии:Название события: Конфере...
# 13  Основные преимущества программы:Возможность об...
# 14  Приглашаем волонтеров принять участие в помощи...
# 15  - одиноким пенсионерам\n- маломобильным гражда...
# ...

# %%
import re
with open("new_rus.txt") as file:
    rus_dict1 = file.read().split()

rus_dict2 = []
for r in rus_dict1:
    if re.match(r'[^а-яё\-]', r.lower()):
        continue
    else:
        rus_dict2.append(r)
len(rus_dict1), len(rus_dict2)
# Out:
# (1647337, 1647337)

# %%
new_data = pd.read_csv("raw_labels_150.csv")
new_data
# Out:
#                                   Неправильный вариант
# 0    Цели проекта:\nСоздание событийно-массового ме...
# 1    Задачи проекта:Формирование культуры инклюзии ...
# 2    Этапы отбора:\nПодача заявок (до 25 июля).\nОн...
# 3    С 1 по 31 июля у вас есть возможность принести...
# 4    В ходе проекта участники научатся:\nперерабаты...
# ..                                                 ...
# 145  - работа с историческими документами в архиве ...
# 146  1. Возможность посмотреть концерт2. Отличная к...
# 147  организовать проведение культурно-досуговых ме...
# 148  Даты проведения мероприятия:21 мая - Главный х...
# 149  ·активизировать творческое воображение;\n·разв...
#
# [150 rows x 1 columns]

# %%
with open("russian.txt", encoding='utf-8') as f:
    tmptmp = f.read().split()
len(tmptmp)
# Out:
# 1532652

# %%
a = '12131'
a[:-1]
# Out:
# '1213'

# %%
import gzip, codecs, tqdm

FILENAME="russian.txt.gz"

with gzip.open(FILENAME) as file:
    with codecs.getreader('utf-8')(file) as text_file:
        rus_dict = text_file.read().split()

ALPHABET = 'йцукенгшщзхъфывапролджэячсмитьбюё-'

rus_by2letters = dict()
for l in ALPHABET:
    rus_by2letters[l] = dict()
    for ll in ALPHABET:
        rus_by2letters[l][ll] = []

cnt = 0

for r in tqdm.tqdm(rus_dict):
    if r[0].isalpha():
        if len(r) > 1:
            if r[1] in rus_by2letters[r[0].lower()].keys():
                rus_by2letters[r[0].lower()][r[1]].append(r)
            if r[-1] == 'ь' and r[:-1] in rus_by2letters[r[0].lower()][r[1]]:
                rus_by2letters[r[0].lower()][r[1]].remove(r[:-1])
                cnt +=1
rus_dict[:20], len(rus_dict), cnt
# Out:
# 100%|██████████| 1532778/1532778 [01:10<00:00, 21892.33it/s]
# (['-де',
#   '-ка',
#   '-либо',
#   '-нибудь',
#   '-с',
#   '-таки',
#   '-то',
#   'а',
#   'а-конто',
#   'а-ля',
#   'а.л.',
#   'аарона',
#   'ааронов',
#   'аб',
#   'аба',
#   'абажур',
#   'абажура',
#   'абажурам',
#   'абажурами',
#   'абажурах'],
#  1532778,
#  6613)

# %%
import os
os.getcwd()
# Out:
# 'd:\\Рабочий стол\\ПРОГА всё\\2023\\на севере кодить\\northcode'

# %%
import re
from math import log

class LanguageModel(object):
  def __init__(self, model_dict):
    # Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).
    self._wordcost = dict((k, log((i+1)*log(len(model_dict)))) for i,k in enumerate(model_dict))
    self._maxword = max(len(x) for x in model_dict)
   

  def split(self, s):
    """Uses dynamic programming to infer the location of spaces in a string without spaces."""
    l = [self._split(x) for x in _SPLIT_RE.split(s)]
    return [item for sublist in l for item in sublist]


  def _split(self, s):
    # Find the best match for the i first characters, assuming cost has
    # been built for the i-1 first characters.
    # Returns a pair (match_cost, match_length).
    def best_match(i):
      candidates = enumerate(reversed(cost[max(0, i-self._maxword):i]))
      return min((c + self._wordcost.get(s[i-k-1:i].lower(), 9e999), k+1) for k,c in candidates)

    # Build the cost array.
    cost = [0]
    for i in range(1,len(s)+1):
      c,k = best_match(i)
      cost.append(c)

    # Backtrack to recover the minimal-cost string.
    out = []
    i = len(s)
    while i>0:
      c,k = best_match(i)
      assert c == cost[i]
      # Apostrophe and digit handling (added by Genesys)
      newToken = True
      if not s[i-k:i] == "'": # ignore a lone apostrophe
        if len(out) > 0:
          # re-attach split 's and split digits
          if out[-1] == "'s" or (s[i-1].isdigit() and out[-1][0].isdigit()): # digit followed by digit
            out[-1] = s[i-k:i] + out[-1] # combine current token with previous token
            newToken = False
      # (End of Genesys addition)

      if newToken:
        out.append(s[i-k:i])

      i -= k

    return reversed(out)

_SPLIT_RE = re.compile("[^а-яёА-ЯЁ0-9']+")

# %%
lm = LanguageModel(rus_dict)

# %%
lm.split('районаблокнотводаблагодарностьверифицированные')
# Out:
# ['района', 'блокнот', 'вода', 'благодарность', 'верифицированные']

# %%
a = """


\"\""""
a = re.sub(r"\n\"{1,}", "\n", a)
a
# Out:
# '\n\n\n'

# %%
import re
from Levenshtein import distance

def minlevdist(badword, dct):
    mindist = 100
    resword = ""
    for w in dct:
        dist = distance(badword, w)
        if dist < mindist:
            mindist = dist
            resword = w
    return mindist, resword

def preproccessing(text):
    text = re.sub(r"(?<=[а-яё0-9a-zA-Z])(?=[А-ЯЁ])", ". ", text)
    text = re.sub(r"(?<=[0-9a-zA-Z])(?=[а-яё])", " ", text)
    text = re.sub(r"(?<=[0-9а-яёА-ЯЁ])(?=[a-z])", " ", text)
    #text = re.sub(r"(?<=[0-9а-яёА-ЯЁa-z])(?=[A-Z])", ". ", text)
    text = re.sub(r"(?<=[а-яёА-ЯЁa-z])(?=[0-9])", " ", text)
    # text = re.sub(r"(?<=[!;\)])(?=[A-Za-zА-ЯЁа-яё0-9])", " ", text)
    # text = re.sub(r"(?<=[:])(?=[A-Za-zА-ЯЁа-яё])", " ", text)
    text = re.sub(r"(?<=[\):])(?=[A-Za-zА-ЯЁа-яё0-9])", " ", text)
    text = re.sub(r"(?<=[!;])(?=[A-Za-zА-ЯЁа-яё0-9 ])", "\n", text)
    text = re.sub(r"(?<=[.])(?=[А-ЯЁа-яё])", "\n", text)
    text = re.sub(r"\n\"{1,}", "\n", text)
    text = re.sub(r'(\d{1}): (\d{2})', r'\1:\2', text)
    text = re.sub(r':\s', r': ', text)
    text = re.sub(r'\"{2,}', r'"', text)
    text = text.replace("&nbsp", "")
    text = re.sub(r'([^a-zA-ZА-ЯЁа-яё0-9])\1+', r'\1', text)
    words = re.split(r'\W', text)
    #words = [re.sub(r'\W+', '', word) for word in words]
    for word in words:
        if re.match(r'^[а-яА-ЯёЁ\-]+$', word) and not word.isupper() and len(word) > 1:
            tmp = word.replace('ё', 'е').lower()
            if tmp not in rus_by2letters[tmp[0]][tmp[1]]:
                #rus.update({tmp})
                if word[0].islower():
                    dist, minword = minlevdist(tmp, rus_by2letters[tmp[0]][tmp[1]])
                    if dist < 3:
                        text = text.replace(word, minword)
                    else:
                        new_words = ' '.join(lm.split(word))
                        text = text.replace(word, new_words)
    #text = text.replace('- ', '-- ').replace(' --', '--').replace(' -', ' --')
    return text

# %%
preproccessing("Привить учщимся любовь к прроде, навыкиповедения в природе и заботиться о ней.")
# Out:
# 'Привить учащимся любовь к природе, навыки поведения в природе и заботиться о ней.'

# %%
from spellchecker import SpellChecker

def correct_spelling(text):
    spell = SpellChecker()
    words = text.split()

    corrected_text = []
    for word in words:
        corrected_word = spell.correction(word)
        corrected_text.append(corrected_word)

    return ' '.join(corrected_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Рабочий стол\ПРОГА всё\2023\на севере кодить\northcode\test.ipynb Ячейка 14 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/%D0%9F%D0%A0%D0%9E%D0%93%D0%90%20%D0%B2%D1%81%D1%91/2023/%D0%BD%D0%B0%20%D1%81%D0%B5%D0%B2%D0%B5%D1%80%D0%B5%20%D0%BA%D0%BE%D0%B4%D0%B8%D1%82%D1%8C/northcode/test.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> from spellchecker import SpellChecker
#       <a href='vscode-notebook-cell:/d%3A/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/%D0%9F%D0%A0%D0%9E%D0%93%D0%90%20%D0%B2%D1%81%D1%91/2023/%D0%BD%D0%B0%20%D1%81%D0%B5%D0%B2%D0%B5%D1%80%D0%B5%20%D0%BA%D0%BE%D0%B4%D0%B8%D1%82%D1%8C/northcode/test.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> def correct_spelling(text):
# ...

# %%
correct_spelling("Привить учщимся любов к прроде, навыкиповедения в природе и заботится о ней.")

# %%
from Levenshtein import distance

dist = []
for idx, row in data.iterrows():
    dist.append(distance(row["Неправильный вариант"], row["Правильный вариант"]))# / len(row["Правильный вариант"]))

# %%
from transformers import AutoModelForSeq2SeqLM, T5TokenizerFast
import pandas as pd
import torch

def test(dataset):
    MODEL_NAME = 'UrukHan/t5-russian-spell'
    loaded_model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)

    # Load the saved weights
    model_path = "spelling_and_punctuation_correction_model.pth"
    loaded_model.load_state_dict(torch.load(model_path))
    loaded_model.eval()

    # Load the tokenizer
    tokenizer = T5TokenizerFast.from_pretrained(MODEL_NAME)

    # Your dataset and input sequences
    dataset = dataset.dropna()
    input_sequences = dataset["Неправильный вариант"]

    task_prefix = "Spell correct: "

    # Tokenize and predict
    MAX_INPUT = 256
    encoded = tokenizer(
        [task_prefix + sequence for sequence in input_sequences],
        padding="max_length",
        max_length=MAX_INPUT,
        truncation=True,
        return_tensors="pt",
    )

    with torch.no_grad():
        predicts = loaded_model.generate(encoded['input_ids'])  # Generate predictions

    decode_prediction = tokenizer.batch_decode(predicts, skip_special_tokens=True)  # Decode predictions

    return decode_prediction

# %%
"jsdjkdsj.lkdsldslkda.dlklskad.dda".rsplit('.', 1)
# Out:
# ['jsdjkdsj.lkdsldslkda.dlklskad', 'dda']

# %%
pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

def add_html_markup(text):
    text = re.sub(r'\s{2,}', ' ', text).strip()
    specsymbols = dict()
    parts = text.split(': ', 1)
    header = ""
    email = re.findall(pattern, text)
    for e in email:
        text = text.replace(e, "<b>" + e + "</b>")
    if ": " in text:
        header = parts[0].strip()
        another = parts[1]
    else:
        if '\n' in text:
            html_text = "<ul>\n"
            tasks = text.split('\n')
            for task in tasks:
                if task.strip() != "":
                    html_text += "  <li>" + task.strip() +  "</li>\n"
            return html_text + "</ul>"
        elif '-' in text:
            html_text = "<ul>\n"
            tasks = text.split('-')
            for task in tasks:
                if task.strip() != "":
                    html_text += "  <li>" + task.strip() +  "</li>\n"
            return html_text + "</ul>"
        elif ';' in text:
            html_text = "<ul>\n"
            tasks = text.split(';')
            for task in tasks:
                if task.strip() != "":
                    html_text += "  <li>" + task.strip() +  "</li>\n"
            return html_text + "</ul>"
        else:
            return "<p>" + text.strip() + "</p>"
        
    prevchar = ""
    for char in text:
        if char == ';' or char == '.' and not prevchar.isdigit() or char == '-' or char == ';' or char == '\n':
            if char not in specsymbols.keys():
                specsymbols[char] = 0
            specsymbols[char] += 1
        prevchar = char
    delim = ';'
    cnt = -1
    for key in specsymbols.keys():
        if cnt < specsymbols[key]:
            cnt = specsymbols[key]
            delim = key
    if cnt != -1:
        tasks = another.split(delim)
        
        html_text = ""
        if header != "":
            html_text += "<p><b>" + header + ":</b></p>\n"
        num_task = len(tasks)
        html_text += "<ul>\n"
        for task in tasks:
            if task.strip() != "":
                if delim != '\n' and tasks[num_task-1] != task:
                    html_text += "  <li>" + task.strip() + delim + "</li>\n"
                else:
                    html_text += "  <li>" + task.strip() + "</li>\n"
        html_text += "</ul>"
    else:
        html_text = "<p>" + text.strip() + "</p>"
    
    
    return html_text

rus = set()
new_dist = []
new_data["model_res"] = ""
ans = list(new_data["Неправильный вариант"])
for i in tqdm.tqdm(range(len(ans))):
    ans[i] = preproccessing(ans[i])
    ans[i] = add_html_markup(ans[i])
    #new_dist.append(distance(ans[idx], row["Правильный вариант"]))# / len(row["Правильный вариант"]))
new_data["model_res"] = pd.Series(ans)
#data["dist"] = pd.Series(new_dist)
# Out:
# ...
# 100%|██████████| 150/150 [00:06<00:00, 24.69it/s]

# %%
import sys

size_bytes = sys.getsizeof(rus_dict)
print(size_bytes / (1024 * 1024))
size_bytes = sys.getsizeof(rus_by2letters)
print(size_bytes)
# Out:
# 12.931266784667969
# 1176

# %%
new_data.to_csv("newdata.csv")
pd.Series(ans).to_csv("ans.csv", index=False)

# %%
# pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'

# def add_html_markup(text):
#     text = re.sub(r'\s{2,}', ' ', text).strip()
#     specsymbols = dict()
#     header = ""
#     email = re.findall(pattern, text)
#     html_text = ""
#     for e in email:
#         text = text.replace(e, "<b>" + e + "</b>")
#     if ": " in text:
#         parts = text.split(': ')
#         for i in range(len(parts) - 1):
#             header = parts[i].strip()
#             print(header, '\n\n')
#             if i == len(parts) - 2:
#                 another = parts[i+1]
#             else:
#                 print(parts[i+1], '\n\n')
#                 tmp = parts[i+1].rsplit('.', 1)
#                 another = tmp[0]
#                 if len(tmp) > 1:
#                     parts[i+1] = tmp[1]
#                 else:
#                     tmp = parts[i+1].rsplit('.', 1)
#                     another = tmp[0]
#                     if len(tmp) > 1:
#                         parts[i+1] = tmp[1]
#                 print(tmp, '\n', parts[i+1], '\n')
#             prevchar = ""
#             for char in another:
#                 if char == ';' or char == '.' and not prevchar.isdigit() or char == '-' or char == ';' or char == '\n':
#                     if char not in specsymbols.keys():
#                         specsymbols[char] = 0
#                     specsymbols[char] += 1
#                 prevchar = char
#             delim = ';'
#             cnt = -1
#             for key in specsymbols.keys():
#                 if cnt < specsymbols[key]:
#                     cnt = specsymbols[key]
#                     delim = key
#             if cnt != -1:
#                 tasks = another.split(delim)
                
#                 if header != "":
#                     html_text += "<p><b>" + header + ":</b></p>\n"
#                 num_task = len(tasks)
#                 html_text += "<ul>\n"
#                 for task in tasks:
#                     if task.strip() != "":
#                         if delim != '\n' and tasks[num_task-1] != task:
#                             html_text += "  <li>" + task.strip() + delim + "</li>\n"
#                         else:
#                             html_text += "  <li>" + task.strip() + "</li>\n"
#                 html_text += "</ul>\n"
#             else:
#                 html_text += "<p>" + another.strip() + "</p>"
            
            
#         return html_text.rstrip()
#     else:
#         if '\n' in text:
#             html_text = "<ul>\n"
#             tasks = text.split('\n')
#             for task in tasks:
#                 if task.strip() != "":
#                     html_text += "  <li>" + task.strip() +  "</li>\n"
#             return html_text + "</ul>"
#         # elif '--' in text:
#         #     html_text = "<ul>\n"
#         #     tasks = text.split('--')
#         #     for task in tasks:
#         #         if task.strip() != "":
#         #             html_text += "  <li>" + task.strip() +  "</li>\n"
#         #     return html_text + "</ul>"
#         else:
#             return "<p>" + text.strip() + "</p>"
        

# rus = set()
# new_dist = []
# data["model_res"] = ""
# ans = list(data["Неправильный вариант"])
# for i in range(len(ans)):
#     ans[i] = preproccessing(ans[i])

# #ans = test(ans)

# for idx, row in data.iterrows():
#     ans[idx] = add_html_markup(ans[idx])
#     new_dist.append(distance(ans[idx], row["Правильный вариант"]))# / len(row["Правильный вариант"]))
# data["model_res"] = pd.Series(ans)
# data["dist"] = pd.Series(new_dist)

# %%
#sum(dist), sum(new_dist)
# Out:
# (3949, 1964)

# %%
import matplotlib.pyplot as plt

plt.plot(dist, label="1")
plt.plot(new_dist, label="2")
plt.legend(fontsize=14, loc=2)

# %%
data_bad = data.copy()
for idx, row in data.iterrows():
    if new_dist[int(idx)] / dist[int(idx)] < 0.7:
        data_bad = data_bad.drop(idx)

# %%
data.to_csv("data.csv")

# %%
import pandas as pd
data["model_res"].to_csv("ans.csv", index=False)
